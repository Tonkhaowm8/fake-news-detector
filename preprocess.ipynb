# %%
import json
import os
import pandas as pd

def read_json_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print("Error: File not found.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def check(data, df, filename):
    authors = ["author", "biographer", "columnist", "creator", "journalist", "producer", "reporter", "writer"]
    dates = [
    "January", "February", "March", "April", 
    "May", "June", "July", "August", 
    "September", "October", "November", "December"]
    author = ""
    date = ""
    text = ""
    label = ""

    if "fake" in filename:
        label = "Fake"
    else:
        label = "Real"

    for item in data:
        # print(item)
        test = item
        try:
            if len(test.replace(" ", "")) > 100:
                text += f"{item} "
                pass
            else:
                for i in authors:
                    if i in item:
                        author = item
                    else:
                        pass
                for j in dates:
                    if j in item:
                        date = item
                    else:
                        pass
        except AttributeError:
            pass
      
        
    print(author)
        # print(f"{str(text)} \n\n") # Don'trun this or your computer explode

    df = df.append({
        'author': author,
        'published': date,
        'title': data[-1][1],
        'text': text,
        'language': "english",
        'site_url': data[-1][0],
        'type': 'bias',
        'label': label,
        'title_without_stopwords': None,
        'text_without_stopwords': None,
        'hasImage': 1}, ignore_index = True)
    
    return df

# %%
# Create a new pandas dataframe
df = pd.DataFrame(columns=['author', 'published', 'title', 'text', 'language', 'site_url', 'main_img_url', 'type', 'label', 'title_without_stopwords', 'text_without_stopwords', 'hasImage'])

directory = 'json'  # Assuming your JSON files are in a directory named 'json'
for filename in os.listdir(directory):
    if filename.endswith('.json'):
        file_path = os.path.join(directory, filename)
        data = read_json_file(file_path)
        if data is not None:
            for i in data:
                df = check(i, df, filename)

print(df)

# %%
print(df["author"])
# Out:
# <bound method NDFrame.head of       author                                          published  \
# 0
# 1             Published:  15:58 GMT, 22 June 2018   |  Updat...
# 2             Published:  20:27 GMT, 18 March 2016   |  Upda...
# 3             The President, an avid social media user, has ...
# 4
# ...      ...                                                ...
# 15176
# 15177
# 15178
# 15179
# 15180
#
#                                                    title  \
# 0      Here's What Really Happened When JFK Jr. Met P...
# 1      Did Miley Cyrus and Liam Hemsworth secretly ge...
# 2      Cindy Crawford's daughter Kaia Gerber wears a ...
# 3      Celebrities Join Tax March in Protest of Donal...
# 4                     Biggest celebrity scandals of 2016
# ...                                                  ...
# 15176  Romneys ProLife Conversion Myth or Reality Jun...
# 15177  deputy director of national health statistics ...
# 15178                           Change We Can Believe In
# 15179  The CNN Miami Republican debate transcript, an...
# 15180                             Interest Group Ratings
#
#                                                     text language  \
# 0      "He was surprised how demure she was." During ...  english
# 1      Congratulations might be in order forMiley Cyr...  english
# 2      We'd venture to say that Cindy Crawford's daug...  english
# 3      Thousands are taking the streets to protest Pr...  english
# 4      or redistributed. ©2024 FOX News Network, LLC....  english
# ...                                                  ...      ...
# 15176                                                     english
# 15177                                                     english
# 15178  Thank you Caroline - for your introduction, yo...  english
# 15179  Donald Trump, Sen. Ted Cruz, Sen. Marco Rubio ...  english
# 15180  2006Senator Obama supported the interests of t...  english
#
#                                                 site_url main_img_url  type  \
# 0      www.townandcountrymag.com/society/tradition/a1...          NaN  bias
# 1      www.dailymail.co.uk/tvshowbiz/article-5874213/...          NaN  bias
# 2      www.dailymail.co.uk/femail/article-3499192/Do-...          NaN  bias
# 3      variety.com/2017/biz/news/tax-march-donald-tru...          NaN  bias
# 4      www.foxnews.com/entertainment/2016/12/16/bigge...          NaN  bias
# ...                                                  ...          ...   ...
# 15176         http://www.youtube.com/watch?v=EhyMplwY6HY          NaN  bias
# 15177         http://www.youtube.com/watch?v=4O8CxZ1OD58          NaN  bias
# 15178  https://web.archive.org/web/20080131000131/htt...          NaN  bias
# 15179  https://www.washingtonpost.com/news/the-fix/wp...          NaN  bias
# 15180  https://web.archive.org/web/20071102131244/htt...          NaN  bias
#
#       label title_without_stopwords text_without_stopwords hasImage
# 0      Fake                    None                   None        1
# 1      Fake                    None                   None        1
# 2      Fake                    None                   None        1
# 3      Fake                    None                   None        1
# 4      Fake                    None                   None        1
# ...     ...                     ...                    ...      ...
# 15176  Real                    None                   None        1
# 15177  Real                    None                   None        1
# 15178  Real                    None                   None        1
# 15179  Real                    None                   None        1
# 15180  Real                    None                   None        1
#
# [15181 rows x 12 columns]>

# %%
print(df)
